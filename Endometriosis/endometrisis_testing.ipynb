# %%
import sys
from pathlib import Path

# Add the OriginalCode directory to the Python path
original_code_path = Path("OriginalCode").resolve()
if original_code_path not in sys.path:
    sys.path.append(str(original_code_path))

# %%
from EnderClassifier import EnderClassifier

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_csv("/home/maciej/Desktop/Maciej/endometriosis/endometriosis.csv")
X = df.drop(columns=['target'])
y = df['target'].astype('int')
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
ender = EnderClassifier(verbose=False)
ender.fit(X_train, y_train, y_test=y_test, X_test=X_test)

# %%
# Done in 1m 28s
ender.evaluate_all_rules()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 519.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 1043.28it/s]

# %%
y_train_pred = ender.predict(X_train)
y_test_pred = ender.predict(X_test)

from CalculateMetrics import calculate_all_metrics

train_metrics = calculate_all_metrics(y_train, y_train_pred)
test_metrics = calculate_all_metrics(y_test, y_test_pred)

# %%
print("Train metrics:")
print(train_metrics)
print("Test metrics:")
print(test_metrics)
# Out:
# Train metrics:
# {'accuracy': 1.0, 'f1': 0.0, 'mean_absolute_error': None}
# Test metrics:
# {'accuracy': 0.8131313131313131, 'f1': 0.0, 'mean_absolute_error': None}

# %%
print("Max train accuracy:", max(ender.history['accuracy']))
print("Max test accuracy:", max(ender.history['accuracy_test']))
# Out:
# Max train accuracy: 1.0
# Max test accuracy: 0.8181818181818182

# %%
y_pred = np.array([np.argmax(pred) for pred in y_test_pred])

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}\n")
print("Classification Report - Test:")
print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
labels = ['No Endometriosis', 'Endometriosis']
print("Confusion Matrix:")
print(f"{'':<20}{labels[0]:<20}{labels[1]:<20}")
print(f"{labels[0]:<20}{cm[0, 0]:<20}{cm[0, 1]:<20}  # True Negative (TN), False Positive (FP)")
print(f"{labels[1]:<20}{cm[1, 0]:<20}{cm[1, 1]:<20}  # False Negative (FN), True Positive (TP)")
# Out:
# Accuracy: 0.81
#
# Classification Report - Test:
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88       150
#            1       0.66      0.48      0.55        48
#
#     accuracy                           0.81       198
#    macro avg       0.75      0.70      0.72       198
# weighted avg       0.80      0.81      0.80       198
#
# Confusion Matrix:
#                     No Endometriosis    Endometriosis
# No Endometriosis    138                 12                    # True Negative (TN), False Positive (FP)
# Endometriosis       25                  23                    # False Negative (FN), True Positive (TP)

# %%
print("XGBoost:")
from xgboost import XGBClassifier

xgb = XGBClassifier()
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}\n")
print("Classification Report - Test:")
print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
labels = ['No Endometriosis', 'Endometriosis']
print("Confusion Matrix:")
print(f"{'':<20}{labels[0]:<20}{labels[1]:<20}")
print(f"{labels[0]:<20}{cm[0, 0]:<20}{cm[0, 1]:<20}  # True Negative (TN), False Positive (FP)")
print(f"{labels[1]:<20}{cm[1, 0]:<20}{cm[1, 1]:<20}  # False Negative (FN), True Positive (TP)")
# Out:
# XGBoost:
# Accuracy: 0.81
#
# Classification Report - Test:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88       150
#            1       0.65      0.50      0.56        48
#
#     accuracy                           0.81       198
#    macro avg       0.75      0.71      0.72       198
# weighted avg       0.80      0.81      0.80       198
#
# Confusion Matrix:
#                     No Endometriosis    Endometriosis
# No Endometriosis    137                 13                    # True Negative (TN), False Positive (FP)
# Endometriosis       24                  24                    # False Negative (FN), True Positive (TP)

# %%
# Ender regressor as classifier
from EnderRegressor import EnderRegressor

ender_regressor = EnderRegressor()
ender_regressor.fit(X_train, y_train)

y_pred = ender_regressor.predict(X_test)
predictions = np.array([0 if pred < 0.5 else 1 for pred in y_pred])

print("Ender Regressor as Classifier")
print(f"Accuracy: {accuracy_score(y_test, predictions):.2f}\n")
print("Classification Report - Test:")
print(classification_report(y_test, predictions))
cm = confusion_matrix(y_test, predictions)
labels = ['No Endometriosis', 'Endometriosis']
print("Confusion Matrix:")
print(f"{'':<20}{labels[0]:<20}{labels[1]:<20}")
print(f"{labels[0]:<20}{cm[0, 0]:<20}{cm[0, 1]:<20}  # True Negative (TN), False Positive (FP)")
print(f"{labels[1]:<20}{cm[1, 0]:<20}{cm[1, 1]:<20}  # False Negative (FN), True Positive (TP)")
# Out:
# default_value (rule): [0.24025974025974026]
# ####################################################################################
# Rule: 1
# 	sex_pain_level >= 3.5
# 	chronic_pain_level >= 0.5
# 	height >= 157.0
# 	age >= 26.5
# 	menstruation_pain >= 5.5
# 	smoking_time <= 23.5
# 	weight <= 114.5
# 	first_menstruation >= 6.5
# 	alcohol_units <= 8.05
# => Decision 0.6870129870129869
#
# ####################################################################################
# Rule: 2
# 	defecation_pain_during <= 1.5
# 	chronic_pain_level <= 3.5
# 	family_endo <= 0.5
# 	menstruation_pain <= 8.5
# 	menstruation_lenght <= 27.0
# 	constipation_during >= 0.5
# 	stomach_ache_apart >= 0.5
# 	cycle <= 45.0
# => Decision -0.2225720620842569
#
# ####################################################################################
# Rule: 3
# 	sex_bleeding <= 0.5
# 	sex_cramps >= 0.5
# 	weight <= 74.0
# 	sex_pain_level <= 6.5
# 	smoking_time >= -2.5
# => Decision 0.7597402597402596
#
# ####################################################################################
# Rule: 4
# 	toparm_pain_during >= 1.5
# 	family_cancer_dig >= 0.5
# 	cycle <= 29.5
# => Decision 0.5307359307359307
#
# ####################################################################################
# Rule: 5
# 	age <= 23.5
# 	height in [162.5, 176.5]
# 	menstruation_pain >= 3.5
# 	birth_weight >= 2775.0
# 	urination_pain_during_level <= 3.5
# 	weight >= 52.0
# 	menstruation_lenght >= 3.5
# 	vaginal_pain_during >= 0.5
# => Decision -0.209560145489498
#
# ####################################################################################
# Rule: 6
# 	vomit_apart >= 1.5
# 	stomach_ache_apart >= 1.5
# 	cycle <= 29.5
# => Decision -0.33073593073593066
#
# ####################################################################################
# Rule: 7
# 	cycle <= 25.5
# 	mood_swings >= 1.5
# 	dizziness <= 1.5
# 	nausea_during >= 1.5
# 	family_cancer <= 0.5
# => Decision 0.6491650535552974
#
# ####################################################################################
# Rule: 8
# 	urination_pain_during_level >= 3.5
# 	infertility <= 0.5
# 	cycle >= 27.0
# => Decision 0.4463203463203464
#
# ####################################################################################
# Rule: 9
# 	sex_pain_level in [1.5, 8.5]
# 	birth_weight <= 3382.0061983471073
# 	age in [24.0, 49.5]
# 	weight in [54.5, 106.5]
# 	urination_pain_apart <= 1.5
# 	first_menstruation <= 14.5
# 	tiredness >= 1.5
# 	menstruation_pain in [5.5, 9.5]
# 	chronic_pain_level <= 8.5
# 	mood_swings >= 1.5
# 	pills <= 1.5
# 	menstruation_lenght <= 11.5
# 	height >= 159.0
# => Decision -0.3545712447744968
#
# ####################################################################################
# Rule: 10
# 	infertility >= 1.5
# 	migraine <= 1.5
# 	smoking_time <= 0.43434343434343436
# 	defecation_blood_during <= 1.5
# 	clots >= 1.5
# 	menstruation_lenght <= 7.5
# 	height <= 171.0
# 	sex_pain_level <= 6.5
# 	sex_bleeding <= 1.5
# 	defecation_pain_apart <= 1.5
# 	back_pain_during >= 0.5
# 	vomit_apart <= 1.5
# 	first_menstruation >= 9.5
# 	age <= 44.5
# => Decision 0.7228198359905674
#
# ####################################################################################
# Rule: 11
# 	height <= 161.5
# 	alcohol_units <= 4.4
# 	menstruation_lenght <= 6.5
# 	chronic_pain_level >= 0.5
# 	constipation_apart <= 1.5
# 	first_menstruation >= 10.5
# 	menstruation_pain >= 2.0
# 	pain_level <= 3.5
# => Decision -0.2517075517075517
#
# ####################################################################################
# Rule: 12
# 	pregnancy in [0.5, 7.5]
# 	pills >= 0.5
# 	abdominal_pressure_during <= 1.5
# 	clots >= 1.5
# 	stomach_ache_apart <= 1.5
# 	weight >= 60.5
# 	chronic_pain_level <= 7.0
# 	nausea_during <= 1.5
# => Decision 0.7254998298900737
#
# ####################################################################################
# Rule: 13
# 	sex_pain_level >= 8.5
# 	infertility >= 0.5
# => Decision 0.2315742533086707
#
# ####################################################################################
# Rule: 14
# 	height <= 167.5
# 	age >= 45.5
# 	first_menstruation >= 12.5
# 	digestive_problems_apart >= 0.5
# 	birth_weight <= 3550.0
# 	urination_pain_during <= 1.5
# => Decision -0.21058346531517264
#
# ####################################################################################
# Rule: 15
# 	age <= 34.5
# 	menstruation_lenght >= 7.5
# 	defecation_blood_during <= 1.5
# 	birth_weight >= 2832.0061983471073
# => Decision -0.28940545385893174
#
# ####################################################################################
# Rule: 16
# 	first_menstruation <= 10.5
# 	chronic_pain_level >= 2.5
# => Decision -0.21671845206774445
#
# ####################################################################################
# Rule: 17
# 	alcohol_units >= 2.3
# 	leg_pain_during >= 1.5
# 	lowerback_pain_apart >= 1.5
# 	height <= 171.5
# => Decision 0.39130473302046054
#
# ####################################################################################
# Rule: 18
# 	birth_weight >= 3435.0
# 	regular_cycle >= 1.5
# 	cycle in [22.0, 31.5]
# 	clots >= 1.5
# 	first_menstruation >= 10.5
# 	sex_pain_level <= 5.5
# 	age >= 24.5
# 	menstruation_pain >= 3.0
# => Decision -0.33039034886270907
#
# ####################################################################################
# Rule: 19
# 	pregnancy <= 7.5
# 	defecation_pain_during >= 1.5
# 	alcohol_units >= 0.6604490500863558
# 	lowerback_pain_during >= 0.5
# 	height <= 172.0
# => Decision 0.27327480353773564
#
# ####################################################################################
# Rule: 20
# 	family_cancer >= 0.5
# 	mood_swings >= 1.5
# 	toparm_pain_during <= 1.5
# 	birth_weight in [2860.0, 3550.0]
# 	pregnancy >= 0.5
# 	height >= 158.5
# 	sex_bleeding >= 0.5
# 	bloody_urine_during <= 1.5
# 	painful_ovulation >= 0.5
# 	urination_pain_during >= 0.5
# 	vaginal_pain_during >= 0.5
# 	age >= 21.5
# 	menstruation_lenght >= 3.5
# 	first_menstruation >= 7.5
# 	night_shift >= 0.5
# 	smoking_time in [-1.0, 24.5]
# 	leg_pain_apart >= 0.5
# 	strong_bleeding >= 0.5
# => Decision -0.15628179619921517
#
# ####################################################################################
# Rule: 21
# 	height in [169.5, 171.5]
# 	strong_bleeding <= 1.5
# 	weight <= 76.5
# 	leg_pain_during <= 1.5
# 	birth_weight <= 4310.0
# => Decision 0.44640217555510137
#
# ####################################################################################
# Rule: 22
# 	menstruation_lenght >= 8.5
# 	pain_level <= 2.5
# 	weight <= 77.5
# => Decision 0.15118190538255216
#
# ####################################################################################
# Rule: 23
# 	sex_pain_level >= 7.5
# 	pulmonary_issues <= 1.5
# 	weight <= 76.5
# 	menstruation_pain >= 6.5
# 	birth_weight <= 4000.0
# 	menstruation_lenght <= 8.5
# => Decision -0.22517190278019733
#
# ####################################################################################
# Rule: 24
# 	sex_pain_level >= 3.5
# 	tiredness <= 1.5
# 	pelvis_pain_during >= 1.5
# 	birth_weight <= 4100.0
# => Decision 0.21898032033346496
#
# ####################################################################################
# Rule: 25
# 	chronic_pain_level >= 7.5
# 	cycle >= 25.5
# 	leg_pain_during >= 1.5
# 	dark_blood >= 1.5
# => Decision 0.21817546343875885
#
# ####################################################################################
# Rule: 26
# 	toparm_pain_during >= 1.5
# 	dizziness <= 1.5
# 	spotting <= 1.5
# 	height <= 176.5
# => Decision -0.20000867116830046
#
# ####################################################################################
# Rule: 27
# 	cycle <= 27.5
# 	tiredness <= 1.5
# 	abdominal_pressure_during >= 1.5
# 	ibs_symptoms <= 1.5
# 	weight >= 57.0
# => Decision -0.1918795775648198
#
# ####################################################################################
# Rule: 28
# 	sex_pain_level <= 1.5
# 	urination_pain_during_level >= 0.5
# => Decision 0.15833144127892088
#
# ####################################################################################
# Rule: 29
# 	weight in [46.0, 56.5]
# 	head_aches >= 1.5
# 	alcohol_units <= 3.1500000000000004
# 	flatulence_during >= 1.5
# 	menstruation_lenght <= 5.5
# 	sex_pain_level <= 5.5
# 	age >= 23.5
# 	bloody_urine_during <= 1.5
# => Decision -0.2082234408588208
#
# ####################################################################################
# Rule: 30
# 	pregnancy <= 6.5
# 	cycle in [27.5, 29.5]
# 	back_pain_apart <= 1.5
# 	age in [34.5, 48.0]
# 	birth_weight <= 3900.0
# 	tiredness <= 1.5
# 	fainting <= 1.5
# 	height >= 161.5
# 	smoking_time <= 11.434343434343434
# => Decision 0.3904767310736442
#
# ####################################################################################
# Rule: 31
# 	bloody_urine_during >= 1.5
# 	urination_pain_apart <= 1.5
# 	lowerback_pain_apart >= 1.5
# 	birth_weight <= 3930.0
# 	pain_level >= 1.0
# 	age >= 25.5
# => Decision -0.1816517985844709
#
# ####################################################################################
# Rule: 32
# 	tiredness <= 1.5
# 	sex_pain_level >= 1.0
# 	mood_swings <= 1.5
# 	weight >= 59.5
# 	first_menstruation <= 13.5
# 	menstruation_lenght >= 3.5
# 	vomit_apart <= 1.5
# => Decision -0.24628725513469277
#
# ####################################################################################
# Rule: 33
# 	nausea_during >= 1.5
# 	alcohol_units <= 1.1604490500863558
# 	urination_pain_during_level <= 0.5
# 	ibs_symptoms >= 1.5
# 	menstruation_pain >= 4.5
# 	menstruation_lenght >= 3.5
# 	height >= 158.5
# 	age >= 22.5
# 	weight in [57.5, 68.5]
# 	birth_weight <= 3682.0061983471073
# => Decision 0.31047169070847813
#
# ####################################################################################
# Rule: 34
# 	birth_weight <= 2590.0
# 	tiredness >= 1.5
# => Decision 0.11266106190839303
#
# ####################################################################################
# Rule: 35
# 	flatulence_apart <= 1.5
# 	clots >= 1.5
# 	pregnancy >= 3.5
# 	digestive_problems_apart <= 1.5
# 	menstruation_pain in [3.5, 9.5]
# 	pelvis_pain_apart <= 1.5
# 	weight in [54.5, 84.0]
# 	smoking_time <= 0.43434343434343436
# 	birth_weight in [2860.0, 3650.0]
# 	menstruation_lenght >= 3.5
# 	height >= 157.5
# 	cycle <= 33.0
# 	hormonal_birthcontrol >= 0.5
# => Decision -0.2227730213551138
#
# ####################################################################################
# Rule: 36
# 	height >= 169.5
# 	menstruation_pain >= 5.5
# 	painful_ovulation <= 1.5
# 	cycle <= 34.5
# 	alcohol_units <= 1.7104490500863558
# 	pregnancy >= 5.5
# 	pain_level <= 2.5
# => Decision 0.1984794209786827
#
# ####################################################################################
# Rule: 37
# 	cramps_during <= 1.5
# 	defecation_pain_during >= 1.5
# => Decision -0.10653360066187262
#
# ####################################################################################
# Rule: 38
# 	sex_pain_level >= 3.5
# 	hormonal_birthcontrol <= 1.5
# 	dizziness <= 1.5
# 	toparm_pain_during <= 1.5
# 	age >= 25.5
# 	height >= 159.5
# 	toparm_pain_apart <= 1.5
# 	weight >= 45.0
# 	smoking_time <= 0.43434343434343436
# 	first_menstruation <= 16.5
# => Decision 0.10078781378323765
#
# ####################################################################################
# Rule: 39
# 	first_menstruation <= 10.5
# 	painful_ovulation <= 1.5
# 	lowerback_pain_during >= 1.5
# => Decision -0.08563905317566034
#
# ####################################################################################
# Rule: 40
# 	vomit_apart >= 1.5
# 	urination_pain_during_level <= 2.0
# 	urinary_infection_symptoms >= 1.5
# 	family_endo <= 0.5
# 	flatulence_apart >= 1.5
# => Decision 0.11702902302315352
#
# ####################################################################################
# Rule: 41
# 	fainting >= 1.5
# 	sex_cramps >= 1.5
# 	menstruation_pain <= 9.5
# 	height <= 170.5
# => Decision -0.12301905363393696
#
# ####################################################################################
# Rule: 42
# 	pulmonary_issues >= 1.5
# 	cycle >= 27.0
# => Decision -0.073491319419699
#
# ####################################################################################
# Rule: 43
# 	weight >= 98.5
# 	family_cancer_dig <= 0.5
# 	pain_level >= 0.5
# 	height >= 163.0
# => Decision -0.05860226797433386
#
# ####################################################################################
# Rule: 44
# 	bowel_movement_during >= 1.5
# 	age >= 30.5
# 	stomach_ache_during >= 1.5
# 	pills >= 0.5
# 	weight in [51.5, 97.0]
# 	vomit_apart <= 1.5
# 	toparm_pain_during >= 0.5
# 	tiredness >= 1.5
# 	sex_pain_level <= 5.5
# 	lowerback_pain_during >= 1.5
# 	menstruation_lenght >= 3.5
# 	birth_weight <= 4150.0
# => Decision 0.1012710346791073
#
# ####################################################################################
# Rule: 45
# 	first_menstruation <= 13.5
# 	cramps_during <= 1.5
# 	cycle >= 29.5
# 	pain_level <= 2.5
# 	birth_weight >= 3150.0
# => Decision -0.12698619578917716
#
# ####################################################################################
# Rule: 46
# 	birth_weight >= 4275.0
# 	strong_bleeding >= 1.5
# 	weight >= 51.5
# => Decision -0.07044234337826318
#
# ####################################################################################
# Rule: 47
# 	sex_pain <= 0.5
# 	height >= 170.5
# => Decision 0.07026136564955558
#
# ####################################################################################
# Rule: 48
# 	birth_weight in [3290.0, 3305.0]
# => Decision -0.05813574088939255
#
# ####################################################################################
# Rule: 49
# 	first_menstruation >= 13.5
# 	family_cancer >= 0.5
# 	height in [170.5, 180.5]
# => Decision 0.09718319485976407
#
# ####################################################################################
# Rule: 50
# 	height >= 171.5
# 	flatulence_apart <= 1.5
# 	clots >= 1.5
# 	weight in [64.0, 103.0]
# 	menstruation_lenght <= 5.5
# 	night_shift <= 1.5
# => Decision -0.09726521638082644
#
# ####################################################################################
# Rule: 51
# 	chronic_pain_level >= 7.5
# 	urinary_infection_symptoms >= 1.5
# 	cycle <= 27.5
# 	flatulence_during >= 1.5
# => Decision -0.09812724179940861
#
# ####################################################################################
# Rule: 52
# 	menstruation_pain >= 8.5
# 	pelvis_pain_during >= 1.5
# 	vaginal_pain_during >= 1.5
# 	urination_pain_during_level <= 2.5
# 	urinary_infection_symptoms >= 1.5
# 	sex_bleeding >= 0.5
# 	height >= 144.5
# => Decision 0.12087318093014554
#
# ####################################################################################
# Rule: 53
# 	cycle >= 38.5
# 	menstruation_pain >= 1.0
# => Decision -0.05510316816222278
#
# ####################################################################################
# Rule: 54
# 	pregnancy <= 3.5
# 	sex_pain_level <= 1.0
# 	diarrhea_during >= 1.5
# 	first_menstruation >= 11.5
# 	height >= 163.5
# 	lowerback_pain_during >= 0.5
# 	bowel_movement_during <= 1.5
# 	birth_weight <= 3925.0
# => Decision 0.13999902152210053
#
# ####################################################################################
# Rule: 55
# 	tiredness <= 1.5
# 	age <= 36.5
# 	family_cancer_dig <= 0.5
# 	back_pain_apart <= 1.5
# 	height in [160.5, 176.0]
# 	diarrhea_apart <= 1.5
# 	weight in [54.5, 68.0]
# 	birth_weight <= 3550.0
# 	cycle >= 26.5
# => Decision -0.10030742338885504
#
# ####################################################################################
# Rule: 56
# 	cycle >= 30.5
# 	alcohol_units >= 3.8499999999999996
# => Decision 0.06309807378510134
#
# ####################################################################################
# Rule: 57
# 	back_pain_apart >= 1.5
# 	abdominal_pressure_apart <= 1.5
# 	lowerback_pain_during >= 1.5
# 	cramps_apart <= 1.5
# 	flatulence_apart >= 1.5
# 	weight in [52.0, 78.5]
# 	age >= 22.5
# 	infertility <= 1.5
# 	pills <= 1.5
# 	height <= 168.5
# 	vaginal_pain_during <= 1.5
# => Decision -0.12011634625559647
#
# ####################################################################################
# Rule: 58
# 	urination_pain_apart >= 1.5
# 	first_menstruation <= 12.5
# 	lowerback_pain_during >= 1.5
# 	birth_weight <= 3425.0
# 	clots >= 1.5
# => Decision 0.06398899444041643
#
# ####################################################################################
# Rule: 59
# 	vaginal_pain_during >= 1.5
# 	constipation_apart <= 1.5
# 	sex_pain_level <= 2.5
# 	age in [20.0, 49.0]
# 	urination_pain_during_level <= 1.5
# 	height >= 162.5
# 	vomit_apart <= 1.5
# 	leg_pain_apart >= 0.5
# 	cycle <= 35.5
# 	stomach_cramps_apart <= 1.5
# 	chronic_pain_level <= 8.5
# 	birth_weight >= 2350.0
# 	weight in [54.5, 125.0]
# 	stomach_ache_during >= 0.5
# 	urination_pain_during <= 1.5
# 	smoking_time >= -1.0
# 	menstruation_lenght >= 3.5
# => Decision -0.04979272341087082
#
# ####################################################################################
# Rule: 60
# 	menstruation_pain <= 1.5
# 	head_aches <= 1.5
# 	weight <= 70.0
# 	pelvis_pain_during <= 1.5
# => Decision 0.13986208173651868
#
# ####################################################################################
# Rule: 61
# 	pain_level >= 3.5
# 	age <= 36.5
# 	head_aches <= 1.5
# 	weight <= 75.5
# 	pregnancy >= 3.0
# => Decision -0.08647306835125973
#
# ####################################################################################
# Rule: 62
# 	birth_weight >= 4225.0
# 	family_cancer_dig <= 0.5
# 	urination_pain_during <= 1.5
# 	cycle <= 35.0
# => Decision 0.05406737086338876
#
# ####################################################################################
# Rule: 63
# 	cycle >= 28.5
# 	dark_blood <= 1.5
# 	birth_weight in [2850.0, 3382.0061983471073]
# 	infertility <= 1.5
# 	first_menstruation <= 14.5
# 	weight >= 55.5
# 	night_shift <= 1.5
# 	fainting <= 1.5
# 	lowerback_pain_during >= 0.5
# 	back_pain_apart <= 1.5
# => Decision 0.1407552006514065
#
# ####################################################################################
# Rule: 64
# 	diarrhea_during <= 1.5
# 	pregnancy >= 7.5
# 	weight <= 63.5
# 	height >= 163.5
# 	birth_weight <= 3750.0
# 	cycle in [13.5, 45.0]
# 	vaginal_pain_apart <= 1.5
# 	spotting >= 0.5
# 	bloody_urine_during <= 1.5
# 	lowerback_pain_apart >= 0.5
# 	sex_cramps <= 1.5
# => Decision -0.04069103162903525
#
# ####################################################################################
# Rule: 65
# 	menstruation_lenght >= 8.5
# 	digestive_problems_during <= 1.5
# 	pregnancy >= 2.5
# => Decision -0.03657512273786393
#
# ####################################################################################
# Rule: 66
# 	sciatica_pain_during >= 1.5
# 	sciatica_pain_apart <= 1.5
# 	tiredness >= 1.5
# 	defecation_pain_during <= 1.5
# 	back_pain_apart <= 1.5
# 	birth_weight >= 3332.0061983471073
# 	age >= 27.5
# => Decision 0.1292599654034382
#
# ####################################################################################
# Rule: 67
# 	abdominal_pressure_during <= 1.5
# 	menstruation_lenght <= 5.5
# 	lowerback_pain_apart <= 1.5
# 	weight >= 57.5
# 	hormonal_birthcontrol >= 0.5
# 	vomit_during <= 1.5
# 	sex_bleeding <= 1.5
# 	height in [161.0, 165.5]
# 	age <= 47.5
# 	pregnancy >= 0.5
# 	cycle <= 28.5
# 	constipation_apart <= 1.5
# 	birth_weight <= 3382.0061983471073
# => Decision -0.08194619043069741
#
# ####################################################################################
# Rule: 68
# 	smoking_time >= 3.5
# 	cycle <= 28.5
# 	sex_pain <= 1.5
# => Decision -0.04614452062469549
#
# ####################################################################################
# Rule: 69
# 	family_endo >= 0.5
# 	ibs_symptoms <= 1.5
# 	weight >= 66.0
# 	menstruation_lenght <= 5.5
# 	pulmonary_issues <= 1.5
# 	back_pain_during >= 0.5
# => Decision 0.06431687747934922
#
# ####################################################################################
# Rule: 70
# 	sex_pain_level >= 4.5
# 	cycle <= 24.5
# 	smoking_time <= 0.43434343434343436
# => Decision -0.05349350008994921
#
# ####################################################################################
# Rule: 71
# 	chronic_pain_level >= 6.5
# 	diarrhea_during >= 1.5
# 	height >= 167.5
# 	first_menstruation >= 11.5
# 	family_endo <= 0.5
# 	leg_pain_apart <= 1.5
# => Decision 0.06949824251021847
#
# ####################################################################################
# Rule: 72
# 	height <= 157.5
# 	defecation_pain_during >= 1.5
# 	weight >= 44.0
# => Decision 0.04710858934265367
#
# ####################################################################################
# Rule: 73
# 	weight >= 94.5
# 	menstruation_pain >= 3.5
# 	toparm_pain_during <= 1.5
# 	birth_weight >= 2100.0
# 	chronic_pain_level <= 6.5
# 	smoking_time <= 7.434343434343434
# => Decision -0.02866868689247226
#
# ####################################################################################
# Rule: 74
# 	fainting >= 1.5
# 	chronic_pain_level <= 8.5
# 	menstruation_lenght >= 4.5
# 	infertility >= 1.5
# => Decision -0.03597958880327137
#
# ####################################################################################
# Rule: 75
# 	birth_weight in [2850.0, 3357.0061983471073]
# 	age <= 32.5
# 	leg_pain_apart <= 1.5
# 	night_shift <= 1.5
# 	painful_ovulation >= 0.5
# 	menstruation_pain <= 9.5
# 	height in [163.5, 173.5]
# 	bowel_movement_apart <= 1.5
# => Decision 0.09125205941911521
#
# ####################################################################################
# Rule: 76
# 	pain_level <= 1.5
# 	flatulence_during >= 1.5
# 	menstruation_lenght <= 5.5
# 	alcohol_units >= 1.7104490500863558
# 	smoking_time <= 0.43434343434343436
# => Decision -0.03219717756135397
#
# ####################################################################################
# Rule: 77
# 	vaginal_pain_apart >= 1.5
# 	menstruation_lenght >= 6.5
# 	regular_cycle >= 1.5
# => Decision -0.0380841694054101
#
# ####################################################################################
# Rule: 78
# 	night_shift >= 1.5
# 	back_pain_during <= 1.5
# 	weight <= 61.0
# 	height >= 162.0
# 	sex_cramps <= 1.5
# 	birth_weight >= 3200.0
# => Decision 0.0760707817167212
#
# ####################################################################################
# Rule: 79
# 	menstruation_pain <= 4.5
# 	menstruation_lenght <= 5.5
# 	weight in [52.5, 96.0]
# 	hormonal_birthcontrol >= 0.5
# 	alcohol_units <= 2.8
# 	height in [154.5, 170.5]
# 	clots >= 0.5
# 	bloody_urine_during <= 1.5
# 	abdominal_pressure_apart <= 1.5
# 	pregnancy >= 0.5
# 	sex_pain >= 0.5
# 	age >= 22.5
# 	fainting <= 1.5
# => Decision -0.025476248753946534
#
# ####################################################################################
# Rule: 80
# 	pain_level >= 2.5
# 	weight <= 58.5
# 	age <= 32.5
# 	sex_pain_level <= 4.5
# 	hormonal_birthcontrol <= 1.5
# 	dark_blood <= 1.5
# => Decision 0.0744378175334708
#
# ####################################################################################
# Rule: 81
# 	sex_cramps <= 0.5
# 	diarrhea_during >= 1.5
# 	head_aches >= 1.5
# => Decision -0.032722801639595164
#
# ####################################################################################
# Rule: 82
# 	vomit_during >= 1.5
# 	menstruation_pain <= 7.5
# 	head_aches >= 1.5
# 	weight >= 60.5
# => Decision 0.03880308117410668
#
# ####################################################################################
# Rule: 83
# 	stomach_ache_apart >= 1.5
# 	lowerback_pain_apart <= 1.5
# 	cycle >= 25.5
# 	weight in [51.0, 139.0]
# 	chronic_pain_level <= 6.5
# 	menstruation_pain >= 2.5
# 	height <= 175.5
# 	smoking_time <= 16.0
# 	birth_weight <= 3875.0
# 	head_aches >= 1.5
# 	age <= 41.0
# 	menstruation_lenght <= 9.0
# => Decision -0.03016488616981381
#
# ####################################################################################
# Rule: 84
# 	defecation_blood_apart >= 1.5
# 	tiredness <= 1.5
# 	sciatica <= 1.5
# => Decision 0.03092443553120881
#
# ####################################################################################
# Rule: 85
# 	leg_pain_apart <= 0.5
# 	diarrhea_apart <= 1.5
# 	cramps_during >= 1.5
# 	constipation_during <= 1.5
# => Decision 0.021081428840676302
#
# ####################################################################################
# Rule: 86
# 	first_menstruation >= 14.5
# 	height <= 164.5
# 	alcohol_units <= 0.6604490500863558
# 	birth_weight <= 3382.0061983471073
# 	menstruation_pain <= 8.5
# 	infertility >= 0.5
# 	regular_cycle >= 0.5
# => Decision -0.03726368863104293
#
# ####################################################################################
# Rule: 87
# 	sex_pain_level <= 1.5
# 	first_menstruation >= 12.5
# 	pain_level >= 1.5
# 	spotting <= 1.5
# 	height in [164.5, 176.5]
# 	diarrhea_apart <= 1.5
# 	family_cancer <= 0.5
# 	stomach_cramps_apart <= 1.5
# 	smoking_time <= 0.43434343434343436
# 	birth_weight >= 3250.0
# 	weight >= 51.5
# => Decision 0.08523467400709221
#
# ####################################################################################
# Rule: 88
# 	head_aches <= 1.5
# 	weight <= 66.5
# 	first_menstruation <= 13.5
# 	constipation_apart <= 1.5
# 	birth_weight >= 3175.0
# 	height >= 162.5
# 	cycle >= 26.5
# 	infertility >= 0.5
# 	pills <= 1.5
# => Decision -0.05547230322389299
#
# ####################################################################################
# Rule: 89
# 	smoking_time >= 0.9343434343434344
# 	hormonal_birthcontrol <= 1.5
# 	vaginal_pain_during <= 1.5
# => Decision 0.025301440538545782
#
# ####################################################################################
# Rule: 90
# 	birth_weight >= 3975.0
# 	cramps_during >= 1.5
# 	vomit_during <= 1.5
# 	sciatica_pain_during <= 1.5
# 	menstruation_lenght >= 3.5
# 	urination_pain_during_level <= 0.5
# => Decision -0.021206932495461194
#
# ####################################################################################
# Rule: 91
# 	cycle >= 27.5
# 	migraine >= 1.5
# 	height in [162.5, 164.5]
# 	defecation_pain_during <= 1.5
# 	birth_weight >= 2925.0
# => Decision 0.046133934731176246
#
# ####################################################################################
# Rule: 92
# 	cycle <= 23.5
# 	menstruation_pain <= 2.5
# 	infertility <= 1.5
# 	first_menstruation <= 14.5
# => Decision -0.026534858135009533
#
# ####################################################################################
# Rule: 93
# 	menstruation_pain <= 1.5
# 	pregnancy <= 9.5
# 	flatulence_apart <= 1.5
# 	height >= 161.5
# 	birth_weight <= 3950.0
# 	cycle >= 25.5
# 	digestive_problems_apart >= 0.5
# => Decision 0.03538677812195392
#
# ####################################################################################
# Rule: 94
# 	head_aches <= 1.5
# 	chronic_pain_level <= 3.5
# 	stomach_ache_during >= 1.5
# 	weight <= 98.0
# 	smoking_time <= 0.43434343434343436
# 	age >= 22.5
# 	sex_pain >= 0.5
# 	menstruation_lenght <= 19.5
# 	sex_bleeding <= 1.5
# 	pain_level >= 1.5
# => Decision -0.0277216256162775
#
# ####################################################################################
# Rule: 95
# 	defecation_pain_during >= 1.5
# 	birth_weight >= 3410.0
# 	menstruation_pain >= 6.5
# 	diarrhea_during >= 1.5
# 	height <= 174.0
# 	strong_bleeding >= 1.5
# 	weight >= 56.0
# => Decision 0.03418011693854178
#
# ####################################################################################
# Rule: 96
# 	leg_pain_apart >= 1.5
# 	age <= 34.5
# 	birth_weight in [2910.0, 3675.0]
# 	pulmonary_issues <= 1.5
# 	cramps_during >= 1.5
# 	cycle >= 4.5
# 	sex_bleeding >= 0.5
# => Decision -0.020635188590683855
#
# ####################################################################################
# Rule: 97
# 	vaginal_pain_during >= 1.5
# 	age <= 32.5
# 	birth_weight <= 3382.0061983471073
# 	leg_pain_apart <= 1.5
# 	height >= 163.5
# 	tiredness >= 1.5
# 	fainting <= 1.5
# => Decision 0.027292087315514954
#
# ####################################################################################
# Rule: 98
# 	urination_pain_apart >= 1.5
# 	weight >= 61.0
# 	urination_pain_during_level <= 0.5
# => Decision 0.01793066211497058
#
# ####################################################################################
# Rule: 99
# 	urination_pain_during_level >= 6.5
# 	bloody_urine_apart <= 1.5
# => Decision 0.009806309988639588
#
# ####################################################################################
# Rule: 100
# 	back_pain_apart >= 1.5
# 	pregnancy >= 5.0
# 	sex_pain_level >= 4.5
# 	sciatica_pain_apart <= 1.5
# 	family_endo <= 0.5
# => Decision -0.029798793203630443
#
# Ender Regressor as Classifier
# Accuracy: 0.79
#
# Classification Report - Test:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       150
#            1       0.56      0.56      0.56        48
#
#     accuracy                           0.79       198
#    macro avg       0.71      0.71      0.71       198
# weighted avg       0.79      0.79      0.79       198
#
# Confusion Matrix:
#                     No Endometriosis    Endometriosis
# No Endometriosis    129                 21                    # True Negative (TN), False Positive (FP)
# Endometriosis       21                  27                    # False Negative (FN), True Positive (TP)
